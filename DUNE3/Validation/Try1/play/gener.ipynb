# %%
# Import packages
from dotenv import load_dotenv
import funwave_ds.fw_py as fpy
import funwave_ds.fw_fs as ffs
import sys
sys.path.append(r'C:\Users\rschanta\OneDrive - University of Delaware - o365\Desktop\Research\FUNWAVE_DS\FUNWAVE_DS\DUNE3\Validation\Try1')
import model_code as mod

# %%
# Define the design matrix
load_dotenv(r'C:\Users\rschanta\OneDrive - University of Delaware - o365\Desktop\Research\FUNWAVE_DS\FUNWAVE_DS\DUNE3\Validation\Try1\envs\Try1.env')
matrix_file = r'C:\Users\rschanta\OneDrive - University of Delaware - o365\Desktop\Research\FUNWAVE_DS\FUNWAVE_DS\DUNE3\Validation\Try1\design_matrices\Try1.csv'

# Loading parameters
load_sets = [mod.load_DUNE3_data]

# Dependent Parameters
function_sets = {'Standard' : [mod.get_spectra,
                               mod.set_spectra,
                               mod.get_bathy,
                               mod.get_hydro,
                               mod.set_bathy]}


# Plot functions
plot_functions = [ffs.plot_1D_bathy,
                  ffs.plot_1D_TS_spectra]

# Filter functions
filter_functions = []

# Print functions
print_functions = [ffs.print_bathy,
                   ffs.print_WK_TIME_SERIES_SPECTRA]


# Write the files
fpy.process_design_matrix_NC(matrix_file, 
                load_sets = load_sets,
                function_sets = function_sets, 
                filter_sets = filter_functions,
                plot_sets = plot_functions,
                print_sets = print_functions)

print('File Generation Script Run!')
# Out:
# Started Directory Creation...
# Directories successfully created!
# SUCCESS: Design matrix has valid ranges/values for all parameters
#
# Started processing permutation: 00000...
#
# Applying DEPENDENCY functions
# 	Applying DEPENDENCY function: get_spectra
# 		Started getting time series for spectra data...
# 4.74572881356175
# 		Successfully made spectra from time series!
# 	Applying DEPENDENCY function: set_spectra
# 		Started cutting spectra to specified frequencies...
# 4.74572881356175
# 		Successfully cut to specified frequencies!
# 	Applying DEPENDENCY function: get_bathy
# 		Started getting bathymetry and MWL...
# 		Finished getting bathymetry and MWL!
# 	Applying DEPENDENCY function: get_hydro
# 		Started getting hydrodynamic variables from dispersion...
# 		Finished getting hydrodynamic variables from dispersion!
# 	Applying DEPENDENCY function: set_bathy
# 		Started setting bathymetry via Pi parameters...
# All DEPENDENCY functions completed successfully!
#
# ...
